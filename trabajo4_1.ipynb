# %% [markdown]
# <a href="https://colab.research.google.com/github/svelasquezso-pixel/trabajos_poo/blob/main/trabajo4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    n1 = float(input("Ingresa la nota 1: "))
    n2 = float(input("Ingresa la nota 2: "))
    n3 = float(input("Ingresa la nota 3: "))

    # Validar rango
    for n in (n1, n2, n3):
        if n < 0 or n > 5:
            raise ValueError("Las notas deben estar entre 0 y 5.")

    promedio = (n1 + n2 + n3) / 3
    print(f"El promedio es: {promedio:.2f}")

except ValueError as e:
    print("Error:", e)

finally:
    print("Fin del programa.")
